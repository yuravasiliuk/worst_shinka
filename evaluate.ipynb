# %%
import subprocess

# %%
pred = subprocess.run(
    ['python', 'train.py'],
     capture_output=True, text=True, timeout=120,
     )

# %%
print(pred.stdout)
# Out:
# Episode: 100 Average Reward: 7 total_num_episodes:  5000
# Episode: 200 Average Reward: 10 total_num_episodes:  5000
# Episode: 300 Average Reward: 11 total_num_episodes:  5000
# Episode: 400 Average Reward: 9 total_num_episodes:  5000
# Episode: 500 Average Reward: 11 total_num_episodes:  5000
# Episode: 600 Average Reward: 12 total_num_episodes:  5000
# Episode: 700 Average Reward: 13 total_num_episodes:  5000
# Episode: 800 Average Reward: 13 total_num_episodes:  5000
# Episode: 900 Average Reward: 17 total_num_episodes:  5000
# Episode: 1000 Average Reward: 18 total_num_episodes:  5000
# Episode: 1100 Average Reward: 20 total_num_episodes:  5000
# Episode: 1200 Average Reward: 20 total_num_episodes:  5000
# Episode: 1300 Average Reward: 20 total_num_episodes:  5000
# Episode: 1400 Average Reward: 25 total_num_episodes:  5000
# Episode: 1500 Average Reward: 30 total_num_episodes:  5000
# Episode: 1600 Average Reward: 31 total_num_episodes:  5000
# ...
